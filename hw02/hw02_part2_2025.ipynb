# %%
# please put the answers of part 1 here, by completing the following strings:

print("The answers of Questions 1 -10:\t 1:B, 2:C, 3:A, 4:A, 5:C, 6:D, 7:C, 8:C, 9:B, 10:C")
print("The answers of Questions 11-20:\t 11:C, 12:A, 13:B, 14:B, 15:D, 16:C, 17:D, 18:A, 19:A, 20:A")
print("The answers of Questions 21-30:\t 21:C, 22:A, 23:A, 24:B, 25:A, 26:C, 27:D, 28:B, 29:C, 30:D")
print("The answers of Questions 31-40:\t 31:C, 32:B, 33:A, 34:A, 35:D, 36:A, 37:B, 38:C, 39:A, 40:D")
print("The answers of Questions 41-50:\t 41:A, 42:B, 43:A, 44:B, 45:A, 46:B, 47:A, 48:B, 49:A, 50:A")
# Out:
# The answers of Questions 1 -10:	 1:B, 2:C, 3:A, 4:A, 5:C, 6:D, 7:C, 8:C, 9:B, 10:C
# The answers of Questions 11-20:	 11:C, 12:A, 13:B, 14:B, 15:D, 16:C, 17:D, 18:A, 19:A, 20:A
# The answers of Questions 21-30:	 21:C, 22:A, 23:A, 24:B, 25:A, 26:C, 27:D, 28:B, 29:C, 30:D
# The answers of Questions 31-40:	 31:C, 32:B, 33:A, 34:A, 35:D, 36:A, 37:B, 38:C, 39:A, 40:D
# The answers of Questions 41-50:	 41:A, 42:B, 43:A, 44:B, 45:A, 46:B, 47:A, 48:B, 49:A, 50:A

# %% [markdown]
# # Defining functions
#
# Let's write a very simple function that converts a proportion to a percentage by multiplying it by 100.  For example, the value of `to_percentage(.5)` should be the number 50.  (No percent sign.)
#
# A function definition has a few parts.
#
# ##### `def`
# It always starts with `def` (short for **def**ine):
#
#     def
#
# ##### Name
# Next comes the name of the function.  Let's call our function `to_percentage`.
#
#     def to_percentage
#
# ##### Signature
# Next comes something called the *signature* of the function.  This tells Python how many arguments your function should have, and what names you'll use to refer to those arguments in the function's code.  `to_percentage` should take one argument, and we'll call that argument `proportion` since it should be a proportion.
#
#     def to_percentage(proportion)
#
# We put a colon after the signature to tell Python it's over.
#
#     def to_percentage(proportion):
#
# ##### Documentation
# Functions can do complicated things, so you should write an explanation of what your function does.  For small functions, this is less important, but it's a good habit to learn from the start.  Conventionally, Python functions are documented by writing a triple-quoted string:
#
#     def to_percentage(proportion):
#         """Converts a proportion to a percentage."""
#
#
# ##### Body
# Now we start writing code that runs when the function is called.  This is called the *body* of the function.  We can write anything we could write anywhere else.  First let's give a name to the number we multiply a proportion by to get a percentage.
#
#     def to_percentage(proportion):
#         """Converts a proportion to a percentage."""
#         factor = 100
#
# ##### `return`
# The special instruction `return` in a function's body tells Python to make the value of the function call equal to whatever comes right after `return`.  We want the value of `to_percentage(.5)` to be the proportion .5 times the factor 100, so we write:
#
#     def to_percentage(proportion):
#         """Converts a proportion to a percentage."""
#         factor = 100
#         return proportion * factor

# %% [markdown]
# **<font color='red'>Question:</font>** Define `to_percentage` in the cell below.  Call your function to convert the proportion .2 to a percentage.  Name that percentage `twenty_percent`.

# %%
def to_percentage(proportion):
    """Converts a proportion to a percentage."""
    factor = 100
    return proportion * factor

twenty_percent = to_percentage(.2)
twenty_percent
# Out:
# 20.0

# %% [markdown]
# Like the built-in functions, you can use named values as arguments to your function.
#
# **<font color='red'>Question:</font>** Use `to_percentage` again to convert the proportion named `a_proportion` (defined below) to a percentage called `a_percentage`.
#
# *Note:* You don't need to define `to_percentage` again!  Just like other named things, functions stick around after you define them.

# %%
a_proportion = 2**(.5) / 2
a_percentage = to_percentage(a_proportion)
a_percentage
# Out:
# 70.71067811865476

# %% [markdown]
# As we've seen with the built-in functions, functions can also take strings (or arrays, or tables) as arguments, and they can return those things, too.
#
# **<font color='red'>Question:</font>** Define a function called `disemvowel`.  It should take a single string as its argument.  (You can call that argument whatever you want.)  It should return a copy of that string, but with all the characters that are vowels removed.  (In English, the vowels are the characters "a", "e", "i", "o", and "u".)
#
# *Hint:* To remove all the "a"s from a string, you can use `that_string.replace("a", "")`.  And you can call `replace` multiple times.

# %%
def disemvowel(a_string):
    str1=a_string.replace("a","")
    str2=str1.replace("e","")
    str3=str2.replace("i","")
    str4=str3.replace("o","")
    return str4.replace("u","")

# An example call to your function.  (It's often helpful to run
# an example call from time to time while you're writing a function,
# to see how it currently works.)
disemvowel("Can you read this without vowels?")
# Out:
# 'Cn y rd ths wtht vwls?'

# %% [markdown]
# ##### Calls on calls on calls
# Just as you write a series of lines to build up a complex computation, it's useful to define a series of small functions that build on each other.  Since you can write any code inside a function's body, you can call other functions you've written.
#
# If a function is a like a recipe, defining a function in terms of other functions is like having a recipe for cake telling you to follow another recipe to make the frosting, and another to make the sprinkles.  This makes the cake recipe shorter and clearer, and it avoids having a bunch of duplicated frosting recipes.  It's a foundation of productive programming.
#
# For example, suppose you want to count the number of characters *that aren't vowels* in a piece of text.  One way to do that is this to remove all the vowels and count the size of the remaining string.
#
# **<font color='red'>Question:</font>** Write a function called `num_non_vowels`.  It should take a string as its argument and return a number.  The number should be the number of characters in the argument string that aren't vowels.
#
# *Hint:* The function `len` takes a string as its argument and returns the number of characters in it.

# %%
def num_non_vowels(a_string):
    """The number of characters in a string, minus the vowels."""
    return len(disemvowel(a_string))

# Try calling your function yourself to make sure the output is what
# you expect. 
num_non_vowels("Can you read this without vowels?")
# Out:
# 22

# %% [markdown]
# **<font color='red'>Question:</font>** Find all possible 4-digit numbers satisfying:
#
# $$abcd\times e = dcba$$
#
# the initial number can not be 0, and $a$, $b$, $c$, $d$ are different numbers.
#
# Print them out.
#
# Hint: you can transfer between string and integer:
#
# ```Python
# >>str(1234)
# [out]: "1234"
# >>int("1234")
# [out]: 1234
# ```

# %%
numlst = []
for num in range(1000,10000):
    strnum = str(num)
    if len(set(strnum)) == 4:
        reverse_num = int(strnum[::-1])
        for e in range(1,10):
            if num*e == reverse_num:
                numlst.append(num)
                break
numlst
# Out:
# [1089, 2178]

# %% [markdown]
# **<font color='red'>Question:</font>**
# Write a function `summation` that evaluates the following summation for $n \geq 1$:
#
# $$\sum_{i=1}^{n} i^3 + 3 i^2$$

# %%
def summation(n):
    """Compute the summation i^3 + 3 * i^2 for 1 <= i <= n."""
    sum = 0
    for i in range(1,n+1):
        sum += i**3 + 3*(i**2)
    return sum
    
# test your function:
summation(500)
# Out:
# 15812937750

# %% [markdown]
# **<font color='red'>Question:</font>**
# Recall the formula for population variance below:
#
# $$\sigma^2 = \frac{\sum_{i=1}^N (x_i - \mu)^2}{N}$$
#
# Complete the functions below to compute the population variance of `population`, an list of numbers. For this question, **do not use built in NumPy functions, such as `np.var`.**

# %%
def mean(population):
    """
    Returns the mean of population (mu)
    
    Keyword arguments:
    population -- a list of numbers
    """
    # Calculate the mean of a population
    sum = 0
    for num in population:
        sum += num
    return sum/len(population)

def variance(population):
    """
    Returns the variance of population (sigma squared)
    
    Keyword arguments:
    population -- a list of numbers
    """
    # Calculate the variance of a population
    mol = 0
    for x in population:
        mol += (x-mean(population))**2
    return mol/len(population)

# %%
# to test the function, at first we generate a list of variables
#that follow a normal distribution:
import numpy as np
population_generated = list(np.random.normal(1,0.3,500))
# test
# note that in each run, the results will differ a bit, 
#because the population we generated each time is ramdom samples

print("The mean of the population is ", mean(population_generated))
print("The variance of the population is ", variance(population_generated))
# Out:
# The mean of the population is  0.9997849100743935
# The variance of the population is  0.10141214672489235

# %% [markdown]
# **<font color='red'>Question:</font>**
# The **GPA**, or **Grade Point Average**, is a number that indicates how well or how high you scored in your courses on average.
# Based on SUSTech's grading system, the scores, Grade and GPA have the following relationship:
#
# | Grade | GPA | Score |
# |:----:|:----:|:--------:|
# | A+   | 4.00 | 97~100   |
# | A    | 3.94 | 93~96    |
# | A-   | 3.85 | 90~92    |
# | B+   | 3.73 | 87~89    |
# | B    | 3.55 | 83~86    |
# | B-   | 3.32 | 80~82    |
# | C+   | 3.09 | 77~79    |
# | C    | 2.78 | 73~76    |
# | C-   | 2.42 | 70~72    |
# | D+   | 2.08 | 67~69    |
# | D    | 1.63 | 63~66    |
# | D-   | 1.15 | 60~62    |
# | F    | 0    | <60      |
#
# Define a function ``Score2GradeGPA`` to convert a score (of total 100) to Grade and GPA according to the table above:

# %%
def Score2GradeGPA(score):
    """
    Returns the Grade and GPA into a tuple.
    
    Keyword arguments:
    score -- an integer or float value in the range [0,100]
    """
    if 97 <= score <= 100:
       grade = 'A+'
       gpa = 4.00
    elif 93 <= score <= 96:
        grade = 'A'
        gpa = 3.94
    elif 90 <= score <= 92:
        grade = 'A-'
        gpa = 3.85
    elif 87 <= score <= 89:
        grade = 'B+'
        gpa = 3.73
    elif 83 <= score <= 86:
        grade = 'B'
        gpa = 3.55
    elif 80 <= score <= 82:
        grade = 'B-'
        gpa = 3.32
    elif 77 <= score <=79:
        grade = 'C+'
        gpa = 3.09
    elif 73 <= score <= 76:
        grade = 'C'
        gpa = 2.78
    elif 70 <= score <=72:
        grade = 'C-'
        gpa = 2.42
    elif 67 <= score <=69:
        grade = 'D+'
        gpa = 2.08
    elif 63 <= score <= 66:
        grade = 'D'
        gpa = 1.63
    elif 60 <= score <=62:
        grade = 'D-'
        gpa = 1.15
    else:
        grade = 'F'
        gpa = 0
    return (grade,gpa)
    
    
# test
# here is the scores of 10 students:
Scores = [50, 60.1, 71, 74.2, 99, 88, 79, 89, 83, 94]
# apply the function:
[Score2GradeGPA(score) for score in Scores]
# Out:
# [('F', 0),
#  ('D-', 1.15),
#  ('C-', 2.42),
#  ('C', 2.78),
#  ('A+', 4.0),
#  ('B+', 3.73),
#  ('C+', 3.09),
#  ('B+', 3.73),
#  ('B', 3.55),
#  ('A', 3.94)]

# %% [markdown]
# # Set

# %% [markdown]
# The **Jaccard index**, also known as the **Jaccard similarity coefficient**, is a statistic used for gauging the similarity and diversity of sample sets. It was developed by Paul Jaccard, and independently formulated again by T. Tanimoto. The Jaccard coefficient measures similarity between finite sample sets, and is defined as the size of the intersection divided by the size of the union of the sample sets:
#
# $$J(A,B)=\frac{|A \cap B|}{|A \cup B|}=\frac{|A \cap B|}{|A|+|B|-|A \cap B|}$$
#
# Now we have list A_l and list B_l:

# %%
A_l = ['h','e','r','a','m','m','y','w','a','r','d','i','s','a','n','a','w','a','r','d',
     'p','r','e','s','e','n','t','e','d','b','y','t','h','e','e','c','o','r','d','i',
     'n','g','c','a','d','e','m','y','t','o','r','e','c','o','g','n','i','z','e','a',
     'c','h','i','e','v','e','m','e','n','t','i','n','t','h','e','m','u','s','i','c',
     'i','n','d','u','s','t','r','y','h','e','t','r','o','p','h','y','d','e','p','i']

B_l = ['s','o','r','i','g','i','n','a','l','a','n','u','a','r','y','d','a','t','e','d',
     'u','e','t','o','t','h','e','i','m','p','a','c','t','o','f','t','h','e','p','a',
     'n','d','e','m','i','c','o','n','t','h','e','m','u','s','i','c','i','n','d','u',
     's','t','r','y','i','n','a','n','d','a','r','o','u','n','d','t','h','e','o','s',
     'n','g','e','l','e','s','o','n','v','e','n','t','i','o','n','e','n','t','e','r']

# %% [markdown]
# **<font color='red'>Question:</font>** Try to define set A and set B based on the corresponding lists A_l and B_l, for set A (or B), the elements are unique members in list A_l (or B_l):

# %%
setA = set()
setB = set()
for a in A_l:
    setA.add(a)
for b in B_l:
    setB.add(b)

# %% [markdown]
# **<font color='red'>Question:</font>** Try to calculate the Jaccard index of A and B, $J(A,B)$:

# %%
len(setA.intersection(setB))/len(setA.union(setB))
# Out:
# 0.7727272727272727

# %% [markdown]
# # String

# %% [markdown]
# The Grammy Award, is an award presented by the Recording Academy to recognize achievement in the music industry. The trophy depicts a gilded gramophone. The annual award ceremony features performances by prominent artists and presentation of awards that showcase achievements made by industry recording artists. The first Grammy Awards ceremony was held on May 4, 1959, to honor the musical accomplishments of performers for the year 1958. After the 2011 ceremony, the Academy overhauled many Grammy Award categories for 2012. The 63rd Annual Grammy Awards were held on March 14, 2021 (after it was postponed from its original January 31, 2021 date due to the impact of the COVID-19 pandemic on the music industry), in and around the Los Angeles Convention Center.
#
# We have the full transcripts of this ceremony, see attached file "Transcripts_63RD_ANNUAL_GRAMMY_AWARDS_2021.txt".

# %% [markdown]
# **<font color='red'>Question:</font>** Read the text from the file, extract all words, convert all words to lower cases, and save them into a list called **word_list**, remove all non-alphabet characters from each word. (Please remove all non-alphabet characters at first, for example, the word '63rd' will become 'rd' after removing the non-aphabet characters.)

# %%
file_path = "E:\SUSTech Program\大二\数据科学导论\HOMEWORK\hw02\Transcripts_63RD_ANNUAL_GRAMMY_AWARDS_2021.txt"
with open(file_path, 'r', encoding='utf-8') as f:
    lists = f.read().split()
    word_list = []

    def remove_non_alphabet_chars(string):
        alphabets = [c for c in string if c.isalpha()]
        return ''.join(alphabets)
    for word in lists:
        clean_word = remove_non_alphabet_chars(word)
        clean_word_lower = clean_word.lower()
        if clean_word_lower:
            word_list.append(clean_word_lower)

# %% [markdown]
# **<font color='red'>Question:</font>** Count the frequency of each unique word in **word_list**, and save the results into a dictionary called **word_count**: each key in the dictionary is a word, and the corresponding value is the frequency.

# %%
from collections import Counter
word_count = Counter(word_list)
word_count
# Out:
# Counter({'the': 679,
#          'i': 569,
#          'and': 543,
#          'to': 447,
#          'you': 434,
#          'a': 378,
#          'me': 243,
#          'of': 233,
#          'my': 233,
#          'it': 208,
#          'is': 200,
#          'that': 196,
#          'for': 185,
#          'in': 183,
#          'this': 173,
#          'im': 161,
#          'we': 147,
#          'so': 146,
#          'on': 135,
#          'up': 132,
#          'like': 129,
#          'all': 117,
#          'applause': 109,
#          'with': 103,
#          'be': 91,
#          'grammy': 86,
#          'its': 85,
#          'but': 83,
#          'was': 83,
#          'dont': 82,
#          'thank': 82,
#          'yeah': 80,
#          'now': 79,
#          'know': 78,
#          'at': 73,
#          'just': 72,
#          'want': 70,
#          'if': 70,
#          'year': 66,
#          'here': 66,
#          'music': 64,
#          'time': 62,
#          'go': 61,
#          'cheers': 61,
#          'are': 60,
#          'got': 59,
#          'when': 59,
#          'have': 58,
#          'who': 57,
#          'your': 55,
#          'say': 55,
#          'they': 54,
#          'been': 52,
#          'baby': 52,
#          'right': 48,
#          'what': 48,
#          'out': 48,
#          'no': 48,
#          'get': 47,
#          'can': 46,
#          'back': 46,
#          'night': 46,
#          'love': 46,
#          'will': 45,
#          'see': 43,
#          'do': 42,
#          'keep': 42,
#          'first': 40,
#          'life': 40,
#          'as': 39,
#          'tonight': 39,
#          'come': 39,
#          'our': 38,
#          'had': 38,
#          'oh': 38,
#          'about': 37,
#          'by': 37,
#          'good': 36,
#          'every': 36,
#          'day': 36,
#          'much': 36,
#          'us': 35,
#          'an': 35,
#          'never': 35,
#          'cant': 35,
#          'he': 35,
#          'from': 34,
#          'thats': 34,
#          'then': 34,
#          'some': 33,
#          'could': 33,
#          'let': 33,
#          'not': 32,
#          'black': 32,
#          'were': 31,
#          'walk': 31,
#          'award': 30,
#          'record': 30,
#          'song': 30,
#          'wanna': 30,
#          'would': 30,
#          'has': 30,
#          'going': 29,
#          'watermelon': 29,
#          'sugar': 29,
#          'one': 28,
#          'because': 28,
#          'people': 28,
#          'make': 28,
#          'need': 28,
#          'trevor': 27,
#          'way': 27,
#          'lets': 27,
#          'high': 27,
#          'youre': 27,
#          'aint': 27,
#          'more': 26,
#          'she': 26,
#          'grammys': 26,
#          'away': 26,
#          'how': 26,
#          'everybody': 25,
#          'cause': 25,
#          'feel': 25,
#          'awards': 24,
#          'even': 24,
#          'down': 24,
#          'ever': 24,
#          'ima': 24,
#          'leave': 24,
#          'where': 23,
#          'everything': 23,
#          'best': 23,
#          'always': 23,
#          'woo': 23,
#          'little': 22,
#          'album': 22,
#          'take': 22,
#          'really': 22,
#          'welcome': 21,
#          'through': 21,
#          'there': 21,
#          'megan': 21,
#          'em': 21,
#          'these': 21,
#          'them': 20,
#          'world': 20,
#          'years': 19,
#          'new': 19,
#          'well': 19,
#          'start': 19,
#          'him': 19,
#          'put': 19,
#          'miss': 19,
#          'made': 18,
#          'whole': 18,
#          'only': 18,
#          'man': 18,
#          'think': 18,
#          'why': 18,
#          'hey': 18,
#          'open': 18,
#          'light': 18,
#          'whats': 18,
#          'home': 18,
#          'tell': 18,
#          'their': 17,
#          'nominated': 17,
#          'look': 17,
#          'amazing': 17,
#          'artist': 17,
#          'into': 17,
#          'very': 17,
#          'or': 17,
#          'than': 16,
#          'heart': 16,
#          'goes': 16,
#          'wow': 16,
#          'colors': 16,
#          'soul': 16,
#          'ill': 16,
#          'door': 16,
#          'gotta': 16,
#          'stallion': 15,
#          'performing': 15,
#          'big': 15,
#          'history': 15,
#          'billie': 15,
#          'her': 15,
#          'okay': 15,
#          'still': 15,
#          'house': 15,
#          'work': 15,
#          'last': 14,
#          'being': 14,
#          'thee': 14,
#          'hear': 14,
#          'also': 14,
#          'dua': 14,
#          'lipa': 14,
#          'hope': 14,
#          'over': 14,
#          'eilish': 14,
#          'said': 14,
#          'favorite': 14,
#          'before': 14,
#          'y': 14,
#          'recording': 14,
#          'happening': 14,
#          'beyonce': 14,
#          'show': 13,
#          'those': 13,
#          'family': 13,
#          'after': 13,
#          'together': 13,
#          'most': 13,
#          'youd': 13,
#          'left': 13,
#          'call': 13,
#          'remember': 13,
#          'did': 13,
#          'academy': 13,
#          'savage': 13,
#          'live': 12,
#          'other': 12,
#          'many': 12,
#          'john': 12,
#          'bring': 12,
#          'coming': 12,
#          'better': 12,
#          'play': 12,
#          'nominations': 12,
#          'hell': 12,
#          'knew': 12,
#          'ive': 12,
#          'money': 12,
#          'announcer': 12,
#          'god': 12,
#          'dance': 12,
#          'hard': 12,
#          'alone': 12,
#          'wet': 12,
#          'everyone': 11,
#          'nominees': 11,
#          'swift': 11,
#          'great': 11,
#          'bad': 11,
#          'dababy': 11,
#          'beautiful': 11,
#          'give': 11,
#          'change': 11,
#          'again': 11,
#          'performance': 11,
#          'next': 11,
#          'stage': 11,
#          'taylor': 11,
#          'present': 11,
#          'today': 11,
#          'ooh': 11,
#          'proud': 11,
#          'done': 11,
#          'wetwetwet': 11,
#          'dynamite': 11,
#          'white': 10,
#          'head': 10,
#          'two': 10,
#          'lil': 10,
#          'cat': 10,
#          'am': 10,
#          'off': 10,
#          'breathe': 10,
#          'same': 10,
#          'wanted': 10,
#          'something': 10,
#          'cbs': 10,
#          'wait': 10,
#          'group': 10,
#          'such': 10,
#          'morning': 10,
#          'yo': 10,
#          'que': 10,
#          'lo': 10,
#          'any': 10,
#          'honored': 10,
#          'came': 10,
#          'ratchet': 10,
#          'long': 9,
#          'perform': 9,
#          'b': 9,
#          'bts': 9,
#          'post': 9,
#          'doja': 9,
#          'roddy': 9,
#          'ricch': 9,
#          'pumas': 9,
#          'watch': 9,
#          'summer': 9,
#          'crazy': 9,
#          'hit': 9,
#          'dream': 9,
#          'understand': 9,
#          'myself': 9,
#          'happy': 9,
#          'shes': 9,
#          'believe': 9,
#          'blue': 9,
#          'brown': 9,
#          'gon': 9,
#          'listen': 9,
#          'gave': 9,
#          'pull': 9,
#          'hitter': 9,
#          'told': 9,
#          'young': 9,
#          'try': 9,
#          'te': 9,
#          'mi': 9,
#          'levitating': 9,
#          'stars': 9,
#          'girl': 9,
#          'waiting': 9,
#          'bigger': 9,
#          'gone': 9,
#          'while': 9,
#          'classy': 9,
#          'bougie': 9,
#          'didnt': 9,
#          'featuring': 9,
#          'city': 9,
#          'rd': 8,
#          'rest': 8,
#          'artists': 8,
#          'malone': 8,
#          'doing': 8,
#          'end': 8,
#          'his': 8,
#          'might': 8,
#          'nobody': 8,
#          'yall': 8,
#          'used': 8,
#          'meet': 8,
#          'anywhere': 8,
#          'sponsored': 8,
#          'youll': 8,
#          'please': 8,
#          'stop': 8,
#          'congratulations': 8,
#          'times': 8,
#          'id': 8,
#          'town': 8,
#          'break': 8,
#          'nothing': 8,
#          'too': 8,
#          'ride': 8,
#          'station': 8,
#          'should': 8,
#          'tu': 8,
#          'de': 8,
#          'since': 8,
#          'part': 8,
#          'pop': 8,
#          'drip': 8,
#          'honor': 8,
#          'sure': 8,
#          'talk': 8,
#          'community': 8,
#          'rain': 8,
#          'bones': 8,
#          'glass': 8,
#          'went': 8,
#          'nasty': 8,
#          'moody': 8,
#          'huh': 8,
#          'fire': 8,
#          'giving': 7,
#          'thing': 7,
#          'wont': 7,
#          'harry': 7,
#          'ladies': 7,
#          'fly': 7,
#          'deserve': 7,
#          'side': 7,
#          'lady': 7,
#          'mama': 7,
#          'important': 7,
#          'special': 7,
#          'lot': 7,
#          'band': 7,
#          'small': 7,
#          'rockstar': 7,
#          'hopin': 7,
#          'known': 7,
#          'inn': 7,
#          'turn': 7,
#          'keeps': 7,
#          'bluebird': 7,
#          'matter': 7,
#          'parade': 7,
#          'sassy': 7,
#          'acting': 7,
#          'stupid': 7,
#          'stuck': 7,
#          'set': 7,
#          'alight': 7,
#          'lovely': 7,
#          'celebrate': 6,
#          'able': 6,
#          'styles': 6,
#          'performances': 6,
#          'cardi': 6,
#          'bruno': 6,
#          'lost': 6,
#          'room': 6,
#          'won': 6,
#          'brother': 6,
#          'without': 6,
#          'king': 6,
#          'getting': 6,
#          'taste': 6,
#          'place': 6,
#          'singing': 6,
#          'felt': 6,
#          'single': 6,
#          'rock': 6,
#          'help': 6,
#          'running': 6,
#          'laughter': 6,
#          'smoke': 6,
#          'ready': 6,
#          'street': 6,
#          'seen': 6,
#          'kind': 6,
#          'til': 6,
#          'nominee': 6,
#          'songs': 6,
#          'cop': 6,
#          'met': 6,
#          'real': 6,
#          'guitar': 6,
#          'glock': 6,
#          'enough': 6,
#          'hitters': 6,
#          'run': 6,
#          'gonna': 6,
#          'wrote': 6,
#          'si': 6,
#          'moonlight': 6,
#          'starlight': 6,
#          'fall': 6,
#          'stay': 6,
#          'plans': 6,
#          'tryna': 6,
#          'past': 6,
#          'independent': 6,
#          'around': 6,
#          'country': 6,
#          'playing': 6,
#          'started': 6,
#          'wildcard': 6,
#          'especially': 6,
#          'moment': 6,
#          'face': 6,
#          'james': 6,
#          'honors': 6,
#          'turned': 6,
#          'storm': 6,
#          'female': 6,
#          'shatter': 6,
#          'wap': 6,
#          'rap': 6,
#          'looking': 6,
#          'thang': 6,
#          'game': 6,
#          'until': 6,
#          'sing': 6,
#          'dynnanana': 6,
#          'nanananana': 6,
#          'nanana': 6,
#          'ten': 5,
#          'feels': 5,
#          'socially': 5,
#          'distance': 5,
#          'prestigious': 5,
#          'lose': 5,
#          'excited': 5,
#          'makes': 5,
#          'each': 5,
#          'top': 5,
#          'mars': 5,
#          'miranda': 5,
#          'lambert': 5,
#          'bunny': 5,
#          'plus': 5,
#          'happened': 5,
#          'both': 5,
#          'guys': 5,
#          'fans': 5,
#          'three': 5,
#          'feelin': 5,
#          'warm': 5,
#          'own': 5,
#          'care': 5,
#          'thought': 5,
#          'daughter': 5,
#          'ago': 5,
#          'sisters': 5,
#          'los': 5,
#          'bed': 5,
#          'gentlemen': 5,
#          'winner': 5,
#          'putting': 5,
#          'making': 5,
#          'films': 5,
#          'mind': 5,
#          'kid': 5,
#          'clean': 5,
#          'heard': 5,
#          'six': 5,
#          'once': 5,
#          'reason': 5,
#          'remain': 5,
#          'car': 5,
#          'bustin': 5,
#          'lay': 5,
#          'fore': 5,
#          'another': 5,
#          'mop': 5,
#          'solo': 5,
#          'joined': 5,
#          'ya': 5,
#          'es': 5,
#          'en': 5,
#          'pongo': 5,
#          'massive': 5,
#          'mine': 5,
#          'eyes': 5,
#          'facebook': 5,
#          'winning': 5,
#          'chance': 5,
#          'sweet': 5,
#          'ah': 5,
#          'venues': 5,
#          'name': 5,
#          'manager': 5,
#          'phone': 5,
#          'kiss': 5,
#          'behind': 5,
#          'count': 5,
#          'dark': 5,
#          'follow': 5,
#          'else': 5,
#          'justin': 5,
#          'continue': 5,
#          'grateful': 5,
#          'molly': 5,
#          'ball': 5,
#          'hotel': 5,
#          'future': 5,
#          'st': 5,
#          'free': 5,
#          'move': 5,
#          'paint': 5,
#          'peel': 5,
#          'person': 5,
#          'write': 5,
#          'box': 5,
#          'beat': 5,
#          'drop': 5,
#          'gang': 5,
#          'theater': 5,
#          'mr': 5,
#          'appallo': 5,
#          'roll': 5,
#          'job': 5,
#          'bleeding': 5,
#          'problem': 5,
#          'freedom': 5,
#          'producer': 5,
#          'shinin': 5,
#          'funk': 5,
#          'motherland': 5,
#          'different': 4,
#          'havent': 4,
#          'block': 4,
#          'forget': 4,
#          'promise': 4,
#          'paak': 4,
#          'pay': 4,
#          'global': 4,
#          'biggest': 4,
#          'guy': 4,
#          'mean': 4,
#          'standing': 4,
#          'wake': 4,
#          'called': 4,
#          'straight': 4,
#          'mess': 4,
#          'share': 4,
#          'spotlight': 4,
#          'ingrid': 4,
#          'shout': 4,
#          'heres': 4,
#          'sky': 4,
#          'brothers': 4,
#          'oohooh': 4,
#          'gray': 4,
#          'alright': 4,
#          'story': 4,
#          'check': 4,
#          'things': 4,
#          'records': 4,
#          'pretty': 4,
#          'greatest': 4,
#          'brand': 4,
#          'lamborghini': 4,
#          'hip': 4,
#          'somebody': 4,
#          'hold': 4,
#          'somethin': 4,
#          'wind': 4,
#          'se': 4,
#          'cuando': 4,
#          'dime': 4,
#          'eres': 4,
#          'siempre': 4,
#          'growing': 4,
#          'far': 4,
#          'took': 4,
#          'stand': 4,
#          'anything': 4,
#          'caring': 4,
#          'bout': 4,
#          'team': 4,
#          'tight': 4,
#          'theres': 4,
#          'talking': 4,
#          'jump': 4,
#          'venue': 4,
#          'thankful': 4,
#          'thanks': 4,
#          'folklore': 4,
#          'old': 4,
#          'hand': 4,
#          'hollywood': 4,
#          'build': 4,
#          'definitely': 4,
#          'golly': 4,
#          'early': 4,
#          'dreams': 4,
#          'changed': 4,
#          'easy': 4,
#          'land': 4,
#          'crack': 4,
#          'voice': 4,
#          'watching': 4,
#          'support': 4,
#          'ask': 4,
#          'songwriters': 4,
#          'fear': 4,
#          'news': 4,
#          'bodyodyodyodyodyodyody': 4,
#          'odyodyodyodyodyodyodyody': 4,
#          'ayy': 4,
#          'bag': 4,
#          'film': 4,
#          'sleep': 4,
#          'join': 4,
#          'jacob': 4,
#          'nostalgia': 4,
#          'overnight': 4,
#          'rb': 4,
#          'inspire': 4,
#          'notice': 4,
#          'woahohoh': 4,
#          'host': 3,
#          'quickly': 3,
#          'lines': 3,
#          'concert': 3,
#          'bringing': 3,
#          'unless': 3,
#          'musical': 3,
#          'weve': 3,
#          'during': 3,
#          'including': 3,
#          'richard': 3,
#          'kenny': 3,
#          'hoping': 3,
#          'forgetting': 3,
#          'announce': 3,
#          'kick': 3,
#          'possible': 3,
#          'dress': 3,
#          'strawberries': 3,
#          'evenin': 3,
#          'sounds': 3,
#          'june': 3,
#          'talented': 3,
#          'mm': 3,
#          'saw': 3,
#          'lie': 3,
#          'wouldnt': 3,
#          'wants': 3,
#          'finneas': 3,
#          'haim': 3,
#          'close': 3,
#          'takin': 3,
#          'mad': 3,
#          'though': 3,
#          'legend': 3,
#          'presenting': 3,
#          'cry': 3,
#          'body': 3,
#          'asked': 3,
#          'gibson': 3,
#          'hazard': 3,
#          'texas': 3,
#          'pier': 3,
#          'souls': 3,
#          'insane': 3,
#          'groups': 3,
#          'quick': 3,
#          'saying': 3,
#          'interviews': 3,
#          'paramount': 3,
#          'someone': 3,
#          'grown': 3,
#          'performer': 3,
#          'use': 3,
#          'extra': 3,
#          'exactly': 3,
#          'pistol': 3,
#          'squeeze': 3,
#          'chop': 3,
#          'hop': 3,
#          'pain': 3,
#          'bucket': 3,
#          'bought': 3,
#          'runnin': 3,
#          'son': 3,
#          'boy': 3,
#          'boom': 3,
#          'front': 3,
#          'may': 3,
#          'soon': 3,
#          'pen': 3,
#          'whip': 3,
#          'guess': 3,
#          'truly': 3,
#          'entere': 3,
#          'nota': 3,
#          'ahi': 3,
#          'donde': 3,
#          'llegao': 3,
#          'sabes': 3,
#          'llevare': 3,
#          'quieres': 3,
#          'beber': 3,
#          'bebe': 3,
#          'quien': 3,
#          'va': 3,
#          'hablar': 3,
#          'nos': 3,
#          'dejamos': 3,
#          'ver': 3,
#          'places': 3,
#          'rhythm': 3,
#          'needed': 3,
#          'doin': 3,
#          'uh': 3,
#          'shoes': 3,
#          'kept': 3,
#          'backstage': 3,
#          'members': 3,
#          'voices': 3,
#          'anderson': 3,
#          'shut': 3,
#          'wing': 3,
#          'playin': 3,
#          'games': 3,
#          'word': 3,
#          'arms': 3,
#          'lalalalalalala': 3,
#          'pandemic': 3,
#          'america': 3,
#          'few': 3,
#          'created': 3,
#          'nashville': 3,
#          'jt': 3,
#          'played': 3,
#          'loss': 3,
#          'along': 3,
#          'category': 3,
#          'recorded': 3,
#          'herself': 3,
#          'assume': 3,
#          'train': 3,
#          'peter': 3,
#          'water': 3,
#          'cardigan': 3,
#          'trend': 3,
#          'less': 3,
#          'wherever': 3,
#          'begging': 3,
#          'wreck': 3,
#          'bieber': 3,
#          'built': 3,
#          'ed': 3,
#          'across': 3,
#          'later': 3,
#          'lives': 3,
#          'fun': 3,
#          'diamond': 3,
#          'youve': 3,
#          'road': 3,
#          'roses': 3,
#          'dew': 3,
#          'happiness': 3,
#          'women': 3,
#          'broke': 3,
#          'painted': 3,
#          'picket': 3,
#          'fences': 3,
#          'worked': 3,
#          'sleeve': 3,
#          'lemons': 3,
#          'mix': 3,
#          'drink': 3,
#          'wide': 3,
#          'stops': 3,
#          'sense': 3,
#          'foundation': 3,
#          'facing': 3,
#          'blow': 3,
#          'earlier': 3,
#          'helped': 3,
#          'circles': 3,
#          'huge': 3,
#          'wish': 3,
#          'fight': 3,
#          'find': 3,
#          'already': 3,
#          'uplift': 3,
#          'low': 3,
#          'key': 3,
#          'jeans': 3,
#          'touch': 3,
#          'act': 3,
#          'kitty': 3,
#          'bentley': 3,
#          'bentayga': 3,
#          'card': 3,
#          'wild': 3,
#          'dry': 3,
#          'winners': 3,
#          'billy': 3,
#          'mitchell': 3,
#          'talent': 3,
#          'audience': 3,
#          'absolutely': 3,
#          'gets': 3,
#          'tied': 3,
#          'queen': 3,
#          'extended': 3,
#          'hollywoods': 3,
#          'scared': 3,
#          'losin': 3,
#          'found': 3,
#          'incredible': 3,
#          'aiko': 3,
#          'collier': 3,
#          'means': 3,
#          'somewhere': 3,
#          'punches': 3,
#          'focused': 3,
#          'candice': 3,
#          'cafe': 3,
#          'songwriter': 3,
#          'chair': 3,
#          'listening': 3,
#          'aye': 3,
#          'zooming': 3,
#          'noah': 2,
#          'throughout': 2,
#          'evening': 2,
#          'tomorrow': 2,
#          'tent': 2,
#          'wedding': 2,
#          'security': 2,
#          'following': 2,
#          'covid': 2,
#          'impressive': 2,
#          'neither': 2,
#          'inside': 2,
#          'unlike': 2,
#          'teenagers': 2,
#          'problems': 2,
#          'worse': 2,
#          'enjoy': 2,
#          'maren': 2,
#          'morris': 2,
#          'tribute': 2,
#          'rogers': 2,
#          'prine': 2,
#          'exciting': 2,
#          'mayer': 2,
#          'babies': 2,
#          'planet': 2,
#          'earth': 2,
#          'full': 2,
#          'haul': 2,
#          'megastar': 2,
#          'steal': 2,
#          'damn': 2,
#          'tastes': 2,
#          'loud': 2,
#          'belly': 2,
#          'diverse': 2,
#          'smash': 2,
#          'honest': 2,
#          'mightve': 2,
#          'nightmare': 2,
#          'golden': 2,
#          'cried': 2,
#          'noticed': 2,
#          'kinda': 2,
#          'hurt': 2,
#          'learn': 2,
#          'yourself': 2,
#          'wonder': 2,
#          'tried': 2,
#          'scream': 2,
#          'weak': 2,
#          'anybody': 2,
#          'angeles': 2,
#          'sit': 2,
#          'steps': 2,
#          'makin': 2,
#          'maybe': 2,
#          'sometimes': 2,
#          'lincoln': 2,
#          'luxury': 2,
#          'suvs': 2,
#          'beatles': 2,
#          'drake': 2,
#          'cuz': 2,
#          'eight': 2,
#          'vibe': 2,
#          'andress': 2,
#          'd': 2,
#          't': 2,
#          'nation': 2,
#          'streaming': 2,
#          'create': 2,
#          'perfect': 2,
#          'streamed': 2,
#          'billions': 2,
#          'remarkable': 2,
#          'director': 2,
#          'revealing': 2,
#          'santa': 2,
#          'monica': 2,
#          'comes': 2,
#          'nomination': 2,
#          'moved': 2,
#          'california': 2,
#          'hate': 2,
#          'headed': 2,
#          'yes': 2,
#          'sir': 2,
#          'oohoohohh': 2,
#          'skies': 2,
#          'luck': 2,
#          'longer': 2,
#          'hiphop': 2,
#          'sensation': 2,
#          'international': 2,
#          'smile': 2,
#          'motivation': 2,
#          'against': 2,
#          'father': 2,
#          'second': 2,
#          'number': 2,
#          'impactful': 2,
#          'longest': 2,
#          'safe': 2,
#          'earned': 2,
#          'nothin': 2,
#          'tears': 2,
#          'goin': 2,
#          'drum': 2,
#          'air': 2,
#          'facetime': 2,
#          'guaranteed': 2,
#          'shoot': 2,
#          'waking': 2,
#          'g': 2,
#          'kill': 2,
#          'ballin': 2,
#          'opps': 2,
#          'fool': 2,
#          ...})

# %% [markdown]
# **<font color='red'>Question:</font>** Based on **word_count**, what's the top 10 frequently used words in this ceremony? Try to print the top 10 words and their frequency below:
#
# Output example:
# ```Python
#     word    frequency:
#     'of'      100
#     'happy'   20
#     ...
# ```

# %%
print("word    frequency:")
for word, freq in word_count.most_common(10):
    print(f" {word:<7}   {freq}")
# Out:
# word    frequency:
#  the       679
#  i         569
#  and       543
#  to        447
#  you       434
#  a         378
#  me        243
#  of        233
#  my        233
#  it        208

# %% [markdown]
# **<font color='red'>Question:</font>** For the top 100 frequently used words, what's top 5 frequently used alphabets? Try to print them out with the percentage they appear in the 100 words:
#
# Output example:
# ```Python
#     alphabet percentage
#     a   10.25%
#     b   20.01%
#     ...
# ```

# %%
alphalist = []
for word in word_count.most_common(100):
    alphalist += list(word[0])
percentage = []
top_alpha = Counter(alphalist).most_common(5)
for i in range(5):
    percentage.append((top_alpha[i][1]/len(alphalist))*100)
print("alphabet    percentage")
for j in range(5):
    print(f"    {top_alpha[j][0]:<8}{percentage[j]:.2f}%")
# Out:
# alphabet    percentage
#     e       10.86%
#     a       9.43%
#     t       9.14%
#     o       8.57%
#     h       6.29%

# %% [markdown]
# # Flip a coin

# %% [markdown]
# Python's built-in ``random`` module, can do the pseudorandom number generation.
# You can get more info. about it here:https://docs.python.org/3/library/random.html
#
# You can import the module:

# %%
import random

# %% [markdown]
#  The method ``random`` in the module ``random`` will return a random values between the interval 0 and 1. For example:

# %%
random.random() # you can run this code multiple times to see how it works.
# Out:
# 0.6591472379466465

# %% [markdown]
# **<font color='red'>Question:</font>** Define a function called ``flip_coin`` that return 0 or 1. Each time we call the function, it will return 0 with probability $p=0.2$, or return 1 with probability $1-p=0.8$. Try to use the method ``random.random()``:

# %%
def flip_coin():
    """
    Return 0 with probability 0.2, or return 1 with probability 0.8
    """
    p = 0.2
    num = random.random()
    if num <= p:
        return 0
    else:
        return 1

# %%
# this code is used for verifying your flip coin function
flip_times = 10000
flip_coin_records = [flip_coin() for i in range(flip_times)]
flip_1 = sum(flip_coin_records)
print ("Flip coins {0} times, in which {1:.3%} are 0, and {2:.3%} are 1.".format(
    flip_times,1-flip_1/flip_times, flip_1/flip_times))
# Out:
# Flip coins 10000 times, in which 19.010% are 0, and 80.990% are 1.

# %% [markdown]
# # Real data analysis

# %% [markdown]
# **<font color='red'>Question: Sales Data Analysis Report Generator</font>**
#
# **Background**
#
# You are a data analyst at an online retail company. The company generates a large amount of sales data daily, which is stored in CSV (Comma-Separated Values) format. Your task is to write a Python program that reads these sales data files, performs a simple analysis, and generates a summary report.
#
# **Data File**
#
# This project uses a real-world e-commerce sales dataset named `data.csv`.
#
#
# **`data.csv` File Format Description**
#
# The file contains the following columns:
#
# *   `InvoiceNo`: The invoice number.
# *   `StockCode`: The product code.
# *   `Quantity`: The quantity of the product per transaction.
# *   `InvoiceDate`: The date and time of the invoice.
# *   `UnitPrice`: The price per unit.
# *   `CustomerID`: The customer's ID.
# *   `Country`: The country where the customer resides.
#
# **Programming Requirements**
#
# You need to write a Python script that completes the following tasks:
#
# 1.  **Read the Data File:**
#     *   Write a function `read_sales_data(file_path)` that takes a file path as an argument.
#     *   Use the `open()` function in read mode (`'r'`) to open the specified CSV file.
#     *   Read the file content line by line and parse each line, converting it into a list of dictionaries. Each row of data should be parsed into a dictionary where the keys are the column names and the values are the corresponding data.
#     *   The function should return this list of dictionaries.
#     *   **Note:** The first line of the CSV file is the header; you need to handle it correctly.
#
# 2.  **Analyze the Data:**
#     *   Write a function `analyze_data(sales_data)` that takes the data returned by the `read_sales_data` function.
#     *   In this function, you need to calculate the following metrics:
#         *   **Total Revenue:** Calculate the total sales amount for all transactions (`Quantity` * `UnitPrice`).
#         *   **Best-Selling Product:** Identify the product with the highest total quantity sold (based on `StockCode`).
#         *   **Top Country by Sales:** Find the country with the highest total sales revenue.
#     *   The function should return a dictionary containing these three metrics.
#
# 3.  **Generate the Report:**
#     *   Write a function `generate_report(analysis_results)` that takes the analysis results from the `analyze_data` function and print the output.
#     *   The report should include:
#         *   A report title
#         *   Total Revenue
#         *   The best-selling product and its total quantity sold
#         *   The top country by sales and its total revenue
#
# **Output**
#
# ```
# Sales Data Analysis Report
#
# --------------------
#
# Total Revenue: 10666684.54
#
# Best-Selling Product:
#   - Product Code: 23843
#   - Total Quantity Sold: 80995
#
# Top Country by Sales:
#   - Country: United Kingdom
#   - Total Revenue: 9025222.08
# ```

# %%
def read_sales_data(file_path:str):
    f=open(file_path,'r')
    data_line = f.read().splitlines()
    InvoiceNo_list = []
    StockCode_list = []
    Quantity_list = []
    InvoiceDate_list = []
    UnitPrice_list = []
    CustomerID_list = []
    Country_list = []
    for i in range(1,len(data_line)):
        init_list = data_line[i].split(',')
        InvoiceNo_list.append(init_list[0])
        StockCode_list.append(init_list[1])
        Quantity_list.append(init_list[2])
        InvoiceDate_list.append(init_list[3])
        UnitPrice_list.append(init_list[4])
        CustomerID_list.append(init_list[5])
        Country_list.append(init_list[6])
    data_dic = {
        'InvoiceNo':InvoiceNo_list,
        'StockCode':StockCode_list,
        'Quantity':Quantity_list,
        'InvoiceDate':InvoiceDate_list,
        'UnitPrice':UnitPrice_list,
        'CustomerID':CustomerID_list,
        'Country':Country_list
    }
    f.close()
    return data_dic

# %%
def analyze_data(sales_data):
    Revenue = 0

    Stockcode_list = []
    Quantity_list = []
    Country_list = []
    Revenue_list = []
    for i in range(len(sales_data['InvoiceNo'])):
        Revenue += int(sales_data['Quantity'][i]) * round(float(sales_data['UnitPrice'][i]),2)

        if sales_data['StockCode'][i] not in Stockcode_list:
            Stockcode_list.append(sales_data['StockCode'][i])
            Quantity_list.append(int(sales_data['Quantity'][i]))
        else:
            for j in range(len(Stockcode_list)):
                if sales_data['StockCode'][i] == Stockcode_list[j]:
                    Quantity_list[j] += int(sales_data['Quantity'][i])

        if sales_data['Country'][i] not in Country_list:
            Country_list.append(sales_data['Country'][i])
            Revenue_list.append(int(sales_data['Quantity'][i])*round(float(sales_data['UnitPrice'][i]),2))
        else:
            for j in range(len(Country_list)):
                if sales_data['Country'][i] == Country_list[j]:
                    Revenue_list[j] += int(sales_data['Quantity'][i])*round(float(sales_data['UnitPrice'][i]),2)
    max_index1 = Quantity_list.index(max(Quantity_list))
    max_index2 = Revenue_list.index(max(Revenue_list))
    Bsproduct = [Stockcode_list[max_index1],Quantity_list[max_index1]]
    Topcountry = [Country_list[max_index2],Revenue_list[max_index2]]

    analyze_dic = {'TotalRevenue': Revenue,
               'Bsproduct': Bsproduct,
               'Topcountry': Topcountry
               }
    return analyze_dic

# %%
def generate_report(analysis_results):
    print("Sales Data Analysis Report")
    print("\n--------------------\n")
    print(f"Total Revenue: {analysis_results['TotalRevenue']:.2f}\n")
    print("Best-Selling Produt:")
    print(f"  - Product Code:{analysis_results['Bsproduct'][0]}")
    print(f"  - Total Quantity Sold:{analysis_results['Bsproduct'][1]}\n")
    print("Top Country by Sales:")
    print("  - Country: ",analysis_results['Topcountry'][0])
    print(f"  - Total Revenue: {analysis_results['Topcountry'][1]:.2f}")

# %%
generate_report(analyze_data(read_sales_data("E:\SUSTech Program\大二\数据科学导论\HOMEWORK\hw02\data.csv")))
# Out:
# Sales Data Analysis Report
#
# --------------------
#
# Total Revenue: 10666684.54
#
# Best-Selling Produt:
#   - Product Code:23843
#   - Total Quantity Sold:80995
#
# Top Country by Sales:
#   - Country:  United Kingdom
#   - Total Revenue: 9025222.08
